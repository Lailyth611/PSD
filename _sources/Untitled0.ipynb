# %%
# load time series dataset
import numpy as np
import pandas as pd
series = pd.read_csv('airline-passengers.csv', header=0, index_col=0)

# %%
# example of defining a dataset
from numpy import array
# define the dataset
data = list()
n = 5000
for i in range(n):
data.append([i+1, (i+1)*10])
data = array(data)
print(data[:5, :])
print(data.shape)
# Out:
#   File "<ipython-input-13-4537e38685d6>", line 7
#     data.append([i+1, (i+1)*10])
#     ^
# IndentationError: expected an indented block
